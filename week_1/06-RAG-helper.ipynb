# %%
from langchain_ollama import ChatOllama

from src.retrieve_documents import retrieve_documents
from src.searching_tool import fit_docs
from src.rag_helper import RAGBase

documents = retrieve_documents()

index = fit_docs(documents)

assistant = RAGBase(
    index=index,
    llm_client=ChatOllama,
)
# Out:
# Number of documents retrieved: 1346

# %%
answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# Yes, you can join. However, if you want to receive a certificate, you need to submit your project while submissions are still being accepted.

# %%
custom_instructions = """
You're a course teaching assistant.
Answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.
""".strip()

assistant = RAGBase(
    index=index,
    llm_client=ChatOllama,
    instructions=custom_instructions,
)

# %%
assistant.rag("How do I get a certificate?")
# Out:
# 'You can only get a certificate if you finish the course with a "live" cohort. Certificates are not awarded for the self-paced mode because you need to peer-review 3 capstone(s) after submitting your project.\n\nTo get the certificate, you need to pass the Capstone project.'

# %%
assistant.rag("Can I still join the course after it started?")
# Out:
# 'You can start whenever you want.'
